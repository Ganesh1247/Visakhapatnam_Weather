# %%
# !pip install xgboost==2.0.0
# Out:
# ...
#    ---------------------------------------- 0.0/99.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/99.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/99.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/99.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/99.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/99.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/99.7 MB ? eta -:--:--
#    ---------------------------------------- 0.3/99.7 MB ? eta -:--:--
#    ---------------------------------------- 0.3/99.7 MB ? eta -:--:--
#    ---------------------------------------- 0.5/99.7 MB 670.4 kB/s eta 0:02:28
#    ---------------------------------------- 0.8/99.7 MB 762.0 kB/s eta 0:02:10
#    ---------------------------------------- 0.8/99.7 MB 762.0 kB/s eta 0:02:10
#    ---------------------------------------- 1.0/99.7 MB 774.0 kB/s eta 0:02:08
# ...

# %%
import pickle

file_path = "xgb_chain_temp_avg.pkl"   # change to your file path

with open(file_path, "rb") as f:
    model = pickle.load(f)

print("Model loaded successfully")
print("Model type:", type(model))
# Out:
# Model loaded successfully
# Model type: <class 'xgboost.sklearn.XGBRegressor'>
# C:\Users\koila\AppData\Local\Temp\ipykernel_21436\3659336369.py:6: UserWarning: [18:58:31] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\data\../common/error_msg.h:83: If you are loading a serialized model (like pickle in Python, RDS in R) or
# configuration generated by an older version of XGBoost, please export the model by calling
# `Booster.save_model` from that version first, then load it back in current version. See:
#
#     https://xgboost.readthedocs.io/en/stable/tutorials/saving_model.html
#
# for more details about differences between saving model and serializing.
#
#   model = pickle.load(f)
